# %%
import matplotlib.pyplot as plt
fig = plt.figure()

# %%
plt.show()

# %%
ax1 = fig.add_subplot(2,2,1)

# %%
fig

# %%
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %%
fig

# %%
plt.plot([1.5,3.5,-2,1.6])
from numpy.random import rand
plt.plot(rand(50).cumsum(),'k--')

# %%
fig

# %%
plt.show()

# %%
ax1.hist(rand(100),bins=20,color='k',alpha=0.3)
# Out:
# (array([  8.,   6.,   6.,   5.,   4.,   4.,   5.,   3.,   3.,   5.,   6.,
#          10.,   9.,   5.,   3.,   4.,   1.,   5.,   4.,   4.]),
#  array([ 0.01559118,  0.06400673,  0.11242228,  0.16083783,  0.20925339,
#          0.25766894,  0.30608449,  0.35450004,  0.40291559,  0.45133114,
#          0.49974669,  0.54816224,  0.59657779,  0.64499334,  0.69340889,
#          0.74182444,  0.79024   ,  0.83865555,  0.8870711 ,  0.93548665,
#          0.9839022 ]),
#  <a list of 20 Patch objects>)

# %%
plt.show()

# %%
fig

# %%
import numpy as np
ax2.scatter(np.arange(30),np.arange(30)+3*rand(30))
fig

# %%
fig,axes = plt.subplots(2,3)

# %%
fig

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1068ffdd8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x106be0390>]], dtype=object)

# %%
fig,axes = plt.subplots(2,2,sharex=True,sharey=True)
fig

# %%
from numpy.random import randn
for i in range(2):
    for j in range(2):
        axes[i,j].hist(randn(500),bins=50,color='k',alpha=0.5)

# %%
fig

# %%
plt.subplots_adjust(wspace=0,hspace=0)

# %%
fig

# %%
fig,axes = plt.subplots(2,2)

# %%
rand(50)
# Out:
# array([ 0.06357555,  0.69502425,  0.49145103,  0.57359227,  0.40820089,
#         0.84374145,  0.03165837,  0.93868056,  0.56404012,  0.74722054,
#         0.66936011,  0.71630206,  0.84903042,  0.59645585,  0.6832339 ,
#         0.59015233,  0.03503148,  0.23243415,  0.28949213,  0.1505913 ,
#         0.19293852,  0.42202109,  0.60682084,  0.39090034,  0.91206389,
#         0.05587931,  0.57247617,  0.44923823,  0.85793762,  0.23323763,
#         0.40798352,  0.06914713,  0.38104945,  0.98306133,  0.98380246,
#         0.94309972,  0.42827973,  0.64546748,  0.8877079 ,  0.025172  ,
#         0.5641007 ,  0.0233418 ,  0.51723934,  0.95412957,  0.3873822 ,
#         0.84302251,  0.45401071,  0.04317327,  0.8135217 ,  0.18992844])

# %%
x,y = randn(50).cumsum(),randn(50).cumsum()
x,y
# Out:
# (array([ -1.58511909,   0.73589585,   2.69586254,   1.94730451,
#           1.83839985,   1.3312193 ,   1.61585453,   1.29241784,
#           0.45729264,   0.30979152,   0.44763701,  -0.1606281 ,
#           0.35575368,   0.87568798,   3.3069448 ,   4.46552648,
#           4.88518069,   5.20601066,   4.51681354,   4.70677436,
#           3.26320594,   2.28807156,   2.5651188 ,   2.48606272,
#           3.06120877,   4.55754467,   6.15952261,   6.50552261,
#           7.41667176,   6.7080011 ,   7.87857446,   6.49768263,
#           8.28800429,   9.067169  ,  10.35497013,  11.9608062 ,
#          10.53160931,  10.64999162,   9.71100659,   9.16096732,
#           8.38148556,   8.64743546,   9.26509768,   7.77457268,
#           7.7583502 ,   9.66360408,   9.75223542,   9.41803212,
#          11.44973013,  12.97412795]),
#  array([-1.69458919, -0.58311019, -0.92354027,  1.06482865, -0.45764427,
#         -1.03594927, -1.57529585, -1.20997329, -0.44642448, -1.2308549 ,
# ...

# %%
axes[0,0].plot(randn(30).cumsum(),color='k',linestyle='dashed',marker='o')
fig

# %%
plt.xlim()
# Out:
# (0.0, 1.0)

# %%
plt.ylim()
# Out:
# (0.0, 1.0)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum())
fig

# %%
ticks = ax.set_xticks([0,250,500,750,1000])
fig

# %%
labels = ax.set_xticklabels(['one','two','three','four','five'],rotation=30,fontsize='small')
fig

# %%
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stage')
fig

# %%
ax.set_yticks([0,15,30,45])
fig

# %%
fig=plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum(),'k',label='one')
ax.plot(randn(1000).cumsum(),'k--',label='two')
ax.plot(randn(1000).cumsum(),'k.',label='three')
ax.legend(loc='best')
fig
plt.show()

# %%
fig.savefig('1.svg')

# %%
plt.savefig('1.svg')

# %%
from pandas import Series, DataFrame
s = Series(np.random.randn(10).cumsum(),index=np.arange(0,100,10))
s.plot()

# %%
plt.show()

# %%
s.plot().savefig('3.svg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-7d6ffb2a42f0> in <module>()
# ----> 1 s.plot().savefig('3.svg')
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
ss = s.plot()

# %%
ss

# %%
ss.savefig('3.svg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-81cca3466bbf> in <module>()
# ----> 1 ss.savefig('3.svg')
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
df = DataFrame(np.random.randn(10,4).cumsum(0),columns=['A','B','C','D'],index=np.arange(0,100,10))
df.plot()
plt.show()

# %%
plt.savefig('4.svg')
